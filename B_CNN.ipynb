# %% [markdown]
# # B-CNN on CIFAR-10

# %% [markdown]
# Author: Yingjie Gong\
# student number: 20144264

# %% [markdown]
# **Description:** \
# Here below is the code implementation of B-CNN model on CIFAR10 dataset\
# 50000 for training, 10000 for testing\
# 60 epochs in total.\
# Learning rate start from 0.003, 0.0005 after 40 epochs\
# 0.0001 after 50 epochs\
# Loss weight is initialized as [0.98, 0.01, 0.01]\
# Referring to https://arxiv.org/abs/1709.09890

# %% [markdown]
# # Packages used

# %%
import keras
import numpy as np
import os
from keras.datasets import cifar10
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras.initializers import he_normal
from keras import optimizers
from keras.callbacks import LearningRateScheduler, TensorBoard
from tensorflow.keras.layers import BatchNormalization
from keras.utils.data_utils import get_file
from keras import backend as K
import tensorflow as tf
import matplotlib.pyplot as plot
import matplotlib.pyplot as plt 
import matplotlib.style as psl
from sklearn.metrics import confusion_matrix      
import seaborn as sn; sn.set(font_scale=1.4)

# %% [markdown]
# # Training settings

# %%
#-------------------- learing rate adjusting rules ----------------------
def scheduler(epoch):
  learning_rate_init = 0.003
  if epoch > 40:
    learning_rate_init = 0.0005
  if epoch > 50:
    learning_rate_init = 0.0001
  return learning_rate_init

#-------------------- loss weight adjusting rules ----------------------
class LossWeightsModifier(keras.callbacks.Callback):
  def __init__(self, alpha, beta, gamma):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
  def on_epoch_end(self, epoch, logs={}):
    if epoch == 8:
      K.set_value(self.alpha, 0.1)
      K.set_value(self.beta, 0.8)
      K.set_value(self.gamma, 0.1)
    if epoch == 18:
      K.set_value(self.alpha, 0.1)
      K.set_value(self.beta, 0.2)
      K.set_value(self.gamma, 0.7)
    if epoch == 28:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0)
      K.set_value(self.gamma, 1)

train_size = 50000

#--- coarse 1 classes ---
num_c_1 = 2
#--- coarse 2 classes ---
num_c_2 = 7
#--- fine classes ---
num_classes  = 10

batch_size   = 128
epochs       = 60

#--- file paths ---
log_filepath = './tb_log_vgg16/'
weights_store_filepath = './vgg16_weights/'
retrain_id = '101'
model_name = 'weights_vgg16_cifar_100_'+retrain_id+'.h5'
model_path = os.path.join(weights_store_filepath, model_name)

#----------get VGG16 pre-trained weights--------
WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5'
weights_path = get_file('vgg16_weights_tf_dim_ordering_tf_kernels.h5',
                         WEIGHTS_PATH,
                         cache_subdir='models')

# %% [markdown]
# # Dimensions

# %%
img_rows, img_cols = 32, 32
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_rows, img_cols)
else:
    input_shape = (img_rows, img_cols, 3)

# %% [markdown]
# # Data loading& preprocess

# %%
#-------------------- data loading ----------------------
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
labels = y_train.flatten()
images = x_train
test_images = x_test
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

#---------------- data preprocessiong -------------------
x_train = (x_train-np.mean(x_train)) / np.std(x_train)
x_test = (x_test-np.mean(x_test)) / np.std(x_test)
print(type(x_train))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# # Data visualizing

# %%
def display_examples(class_names, images, labels, title = "Some examples of images of the dataset"):
    """
        Display 25 images from the images array with its corresponding labels
    """

    fig = plt.figure(figsize=(10,10))
    fig.suptitle(title, fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i],cmap = 'gray')
        plt.xlabel(class_names[labels[i]])
    plt.show()

#---------------------- calling to show --------------------------
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
display_examples(classes, images, labels)

# %% [markdown]
# # Create Labels for 2 coarses

# %%
#---------------------- make coarse 2 labels --------------------------
parent_f = {
  2:3, 3:5, 5:5,
  1:2, 7:6, 4:6,
  0:0, 6:4, 8:1, 9:2
}
y_c2_train = np.zeros((y_train.shape[0], num_c_2)).astype("float32")
y_c2_test = np.zeros((y_test.shape[0], num_c_2)).astype("float32")
for i in range(y_c2_train.shape[0]):
  y_c2_train[i][parent_f[np.argmax(y_train[i])]] = 1.0
for i in range(y_c2_test.shape[0]):
  y_c2_test[i][parent_f[np.argmax(y_test[i])]] = 1.0

#---------------------- make coarse 1 labels --------------------------
parent_c2 = {
  0:0, 1:0, 2:0,
  3:1, 4:1, 5:1, 6:1
}
y_c1_train = np.zeros((y_c2_train.shape[0], num_c_1)).astype("float32")
y_c1_test = np.zeros((y_c2_test.shape[0], num_c_1)).astype("float32")
for i in range(y_c1_train.shape[0]):
  y_c1_train[i][parent_c2[np.argmax(y_c2_train[i])]] = 1.0
for i in range(y_c1_test.shape[0]):
  y_c1_test[i][parent_c2[np.argmax(y_c2_test[i])]] = 1.0

# %% [markdown]
# # Model Definition

# %%
#----------------------- model definition ---------------------------
alpha = K.variable(value=0.98, dtype="float32", name="alpha") 
beta = K.variable(value=0.01, dtype="float32", name="beta") 
gamma = K.variable(value=0.01, dtype="float32", name="gamma") 

img_input = Input(shape=input_shape, name='input')

#--- block 1 ---
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

#--- block 2 ---
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

#--- coarse 1 branch ---
c_1_bch = Flatten(name='c1_flatten')(x)
c_1_bch = Dense(256, activation='relu', name='c1_fc_cifar10_1')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_bch = Dense(256, activation='relu', name='c1_fc2')(c_1_bch)
c_1_bch = BatchNormalization()(c_1_bch)
c_1_bch = Dropout(0.5)(c_1_bch)
c_1_pred = Dense(num_c_1, activation='softmax', name='c1_predictions_cifar10')(c_1_bch)

#--- block 3 ---
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

#--- coarse 2 branch ---
c_2_bch = Flatten(name='c2_flatten')(x)
c_2_bch = Dense(512, activation='relu', name='c2_fc_cifar10_1')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_bch = Dense(512, activation='relu', name='c2_fc2')(c_2_bch)
c_2_bch = BatchNormalization()(c_2_bch)
c_2_bch = Dropout(0.5)(c_2_bch)
c_2_pred = Dense(num_c_2, activation='softmax', name='c2_predictions_cifar10')(c_2_bch)

#--- block 4 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

#--- block 5 ---
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
x = BatchNormalization()(x)

#--- fine block ---
x = Flatten(name='flatten')(x)
x = Dense(4096, activation='relu', name='fc_cifar100_1')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(4096, activation='relu', name='fc_cifar100_2')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
fine_pred = Dense(num_classes, activation='softmax', name='predictions_cifar10')(x)

model = Model(img_input, [c_1_pred, c_2_pred, fine_pred], name='vgg16_hierarchy')
model.load_weights(weights_path, by_name=True)

# %% [markdown]
# # Compile and Fit

# %%
#----------------------- compile and fit ---------------------------
sgd = tf.keras.optimizers.SGD(lr=0.001, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd, 
              loss_weights=[alpha, beta, gamma], 
              # optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
tb_cb = TensorBoard(log_dir=log_filepath, histogram_freq=0)
change_lr = LearningRateScheduler(scheduler)
change_lw = LossWeightsModifier(alpha, beta, gamma)
cbks = [change_lr, tb_cb, change_lw]

trained = model.fit(x_train, [y_c1_train, y_c2_train, y_train],
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          callbacks=cbks,
          validation_data=(x_test, [y_c1_test, y_c2_test, y_test]))


model.compile(loss=keras.losses.categorical_crossentropy,
              # optimizer=keras.optimizers.Adadelta(),
              optimizer=sgd, 
              metrics=['accuracy'])

model.save(model_path)
score = model.evaluate(x_test, [y_c1_test, y_c2_test, y_test], verbose=0)
print('score is: ', score)
# Out:
# C:\Users\25863\anaconda3\envs\Tensor_NIVDA\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/60
#   5/391 [..............................] - ETA: 1:20 - loss: 1.0729 - c1_predictions_cifar10_loss: 1.0257 - c2_predictions_cifar10_loss: 3.1228 - predictions_cifar10_loss: 3.6444 - c1_predictions_cifar10_accuracy: 0.5813 - c2_predictions_cifar10_accuracy: 0.1578 - predictions_cifar10_accuracy: 0.0969 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0211s vs `on_train_batch_end` time: 0.1276s). Check your callbacks.
# 391/391 [==============================] - 30s 48ms/step - loss: 0.3147 - c1_predictions_cifar10_loss: 0.2690 - c2_predictions_cifar10_loss: 2.5751 - predictions_cifar10_loss: 2.5278 - c1_predictions_cifar10_accuracy: 0.8964 - c2_predictions_cifar10_accuracy: 0.2502 - predictions_cifar10_accuracy: 0.2961 - val_loss: 0.1915 - val_c1_predictions_cifar10_loss: 0.1691 - val_c2_predictions_cifar10_loss: 1.2981 - val_predictions_cifar10_loss: 1.2779 - val_c1_predictions_cifar10_accuracy: 0.9302 - val_c2_predictions_cifar10_accuracy: 0.5299 - val_predictions_cifar10_accuracy: 0.5579
# Epoch 2/60
# 391/391 [==============================] - 16s 42ms/step - loss: 0.2117 - c1_predictions_cifar10_loss: 0.1790 - c2_predictions_cifar10_loss: 1.8392 - predictions_cifar10_loss: 1.7883 - c1_predictions_cifar10_accuracy: 0.9307 - c2_predictions_cifar10_accuracy: 0.4184 - predictions_cifar10_accuracy: 0.4755 - val_loss: 0.1737 - val_c1_predictions_cifar10_loss: 0.1552 - val_c2_predictions_cifar10_loss: 1.0418 - val_predictions_cifar10_loss: 1.1179 - val_c1_predictions_cifar10_accuracy: 0.9349 - val_c2_predictions_cifar10_accuracy: 0.6261 - val_predictions_cifar10_accuracy: 0.6213
# Epoch 3/60
# 391/391 [==============================] - 16s 42ms/step - loss: 0.1812 - c1_predictions_cifar10_loss: 0.1533 - c2_predictions_cifar10_loss: 1.5493 - predictions_cifar10_loss: 1.5471 - c1_predictions_cifar10_accuracy: 0.9406 - c2_predictions_cifar10_accuracy: 0.5018 - predictions_cifar10_accuracy: 0.5459 - val_loss: 0.1549 - val_c1_predictions_cifar10_loss: 0.1382 - val_c2_predictions_cifar10_loss: 0.9216 - val_predictions_cifar10_loss: 1.0247 - val_c1_predictions_cifar10_accuracy: 0.9460 - val_c2_predictions_cifar10_accuracy: 0.6667 - val_predictions_cifar10_accuracy: 0.6593
# Epoch 4/60
# 391/391 [==============================] - 17s 43ms/step - loss: 0.1590 - c1_predictions_cifar10_loss: 0.1338 - c2_predictions_cifar10_loss: 1.3857 - predictions_cifar10_loss: 1.4011 - c1_predictions_cifar10_accuracy: 0.9485 - c2_predictions_cifar10_accuracy: 0.5503 - predictions_cifar10_accuracy: 0.5854 - val_loss: 0.1470 - val_c1_predictions_cifar10_loss: 0.1315 - val_c2_predictions_cifar10_loss: 0.8539 - val_predictions_cifar10_loss: 0.9639 - val_c1_predictions_cifar10_accuracy: 0.9459 - val_c2_predictions_cifar10_accuracy: 0.6953 - val_predictions_cifar10_accuracy: 0.6799
# Epoch 5/60
# 391/391 [==============================] - 16s 42ms/step - loss: 0.1423 - c1_predictions_cifar10_loss: 0.1190 - c2_predictions_cifar10_loss: 1.2772 - predictions_cifar10_loss: 1.2935 - c1_predictions_cifar10_accuracy: 0.9549 - c2_predictions_cifar10_accuracy: 0.5870 - predictions_cifar10_accuracy: 0.6154 - val_loss: 0.1359 - val_c1_predictions_cifar10_loss: 0.1213 - val_c2_predictions_cifar10_loss: 0.8006 - val_predictions_cifar10_loss: 0.9078 - val_c1_predictions_cifar10_accuracy: 0.9525 - val_c2_predictions_cifar10_accuracy: 0.7165 - val_predictions_cifar10_accuracy: 0.6999
# Epoch 6/60
# 391/391 [==============================] - 17s 42ms/step - loss: 0.1297 - c1_predictions_cifar10_loss: 0.1076 - c2_predictions_cifar10_loss: 1.1984 - predictions_cifar10_loss: 1.2179 - c1_predictions_cifar10_accuracy: 0.9593 - c2_predictions_cifar10_accuracy: 0.6123 - predictions_cifar10_accuracy: 0.6347 - val_loss: 0.1302 - val_c1_predictions_cifar10_loss: 0.1162 - val_c2_predictions_cifar10_loss: 0.7621 - val_predictions_cifar10_loss: 0.8715 - val_c1_predictions_cifar10_accuracy: 0.9536 - val_c2_predictions_cifar10_accuracy: 0.7319 - val_predictions_cifar10_accuracy: 0.7140
# Epoch 7/60
# 391/391 [==============================] - 16s 42ms/step - loss: 0.1167 - c1_predictions_cifar10_loss: 0.0960 - c2_predictions_cifar10_loss: 1.1305 - predictions_cifar10_loss: 1.1350 - c1_predictions_cifar10_accuracy: 0.9629 - c2_predictions_cifar10_accuracy: 0.6343 - predictions_cifar10_accuracy: 0.6547 - val_loss: 0.1397 - val_c1_predictions_cifar10_loss: 0.1265 - val_c2_predictions_cifar10_loss: 0.7341 - val_predictions_cifar10_loss: 0.8449 - val_c1_predictions_cifar10_accuracy: 0.9511 - val_c2_predictions_cifar10_accuracy: 0.7424 - val_predictions_cifar10_accuracy: 0.7225
# Epoch 8/60
# 391/391 [==============================] - 16s 42ms/step - loss: 0.1065 - c1_predictions_cifar10_loss: 0.0863 - c2_predictions_cifar10_loss: 1.0994 - predictions_cifar10_loss: 1.0860 - c1_predictions_cifar10_accuracy: 0.9673 - c2_predictions_cifar10_accuracy: 0.6436 - predictions_cifar10_accuracy: 0.6699 - val_loss: 0.1274 - val_c1_predictions_cifar10_loss: 0.1144 - val_c2_predictions_cifar10_loss: 0.7111 - val_predictions_cifar10_loss: 0.8171 - val_c1_predictions_cifar10_accuracy: 0.9553 - val_c2_predictions_cifar10_accuracy: 0.7512 - val_predictions_cifar10_accuracy: 0.7319
# Epoch 9/60
# 391/391 [==============================] - 16s 42ms/step - loss: 0.0973 - c1_predictions_cifar10_loss: 0.0783 - c2_predictions_cifar10_loss: 1.0302 - predictions_cifar10_loss: 1.0260 - c1_predictions_cifar10_accuracy: 0.9703 - c2_predictions_cifar10_accuracy: 0.6599 - predictions_cifar10_accuracy: 0.6887 - val_loss: 0.1254 - val_c1_predictions_cifar10_loss: 0.1129 - val_c2_predictions_cifar10_loss: 0.6907 - val_predictions_cifar10_loss: 0.7907 - val_c1_predictions_cifar10_accuracy: 0.9569 - val_c2_predictions_cifar10_accuracy: 0.7583 - val_predictions_cifar10_accuracy: 0.7430
# Epoch 10/60
# 391/391 [==============================] - 17s 42ms/step - loss: 0.6761 - c1_predictions_cifar10_loss: 0.0691 - c2_predictions_cifar10_loss: 0.7173 - predictions_cifar10_loss: 0.9540 - c1_predictions_cifar10_accuracy: 0.9737 - c2_predictions_cifar10_accuracy: 0.7577 - predictions_cifar10_accuracy: 0.7102 - val_loss: 0.4531 - val_c1_predictions_cifar10_loss: 0.1123 - val_c2_predictions_cifar10_loss: 0.4677 - val_predictions_cifar10_loss: 0.6772 - val_c1_predictions_cifar10_accuracy: 0.9561 - val_c2_predictions_cifar10_accuracy: 0.8389 - val_predictions_cifar10_accuracy: 0.7795
# Epoch 11/60
# 391/391 [==============================] - 17s 45ms/step - loss: 0.4619 - c1_predictions_cifar10_loss: 0.0679 - c2_predictions_cifar10_loss: 0.4777 - predictions_cifar10_loss: 0.7296 - c1_predictions_cifar10_accuracy: 0.9752 - c2_predictions_cifar10_accuracy: 0.8335 - predictions_cifar10_accuracy: 0.7713 - val_loss: 0.3903 - val_c1_predictions_cifar10_loss: 0.1140 - val_c2_predictions_cifar10_loss: 0.3991 - val_predictions_cifar10_loss: 0.5965 - val_c1_predictions_cifar10_accuracy: 0.9568 - val_c2_predictions_cifar10_accuracy: 0.8622 - val_predictions_cifar10_accuracy: 0.8071
# Epoch 12/60
# 391/391 [==============================] - 17s 44ms/step - loss: 0.3738 - c1_predictions_cifar10_loss: 0.0657 - c2_predictions_cifar10_loss: 0.3855 - predictions_cifar10_loss: 0.5886 - c1_predictions_cifar10_accuracy: 0.9763 - c2_predictions_cifar10_accuracy: 0.8648 - predictions_cifar10_accuracy: 0.8105 - val_loss: 0.3631 - val_c1_predictions_cifar10_loss: 0.1117 - val_c2_predictions_cifar10_loss: 0.3695 - val_predictions_cifar10_loss: 0.5630 - val_c1_predictions_cifar10_accuracy: 0.9577 - val_c2_predictions_cifar10_accuracy: 0.8733 - val_predictions_cifar10_accuracy: 0.8208
# Epoch 13/60
# 391/391 [==============================] - 17s 44ms/step - loss: 0.3152 - c1_predictions_cifar10_loss: 0.0644 - c2_predictions_cifar10_loss: 0.3238 - predictions_cifar10_loss: 0.4971 - c1_predictions_cifar10_accuracy: 0.9753 - c2_predictions_cifar10_accuracy: 0.8872 - predictions_cifar10_accuracy: 0.8356 - val_loss: 0.3449 - val_c1_predictions_cifar10_loss: 0.1086 - val_c2_predictions_cifar10_loss: 0.3488 - val_predictions_cifar10_loss: 0.5505 - val_c1_predictions_cifar10_accuracy: 0.9597 - val_c2_predictions_cifar10_accuracy: 0.8833 - val_predictions_cifar10_accuracy: 0.8258
# Epoch 14/60
# 391/391 [==============================] - 18s 45ms/step - loss: 0.2724 - c1_predictions_cifar10_loss: 0.0629 - c2_predictions_cifar10_loss: 0.2798 - predictions_cifar10_loss: 0.4227 - c1_predictions_cifar10_accuracy: 0.9769 - c2_predictions_cifar10_accuracy: 0.9021 - predictions_cifar10_accuracy: 0.8581 - val_loss: 0.3343 - val_c1_predictions_cifar10_loss: 0.1147 - val_c2_predictions_cifar10_loss: 0.3376 - val_predictions_cifar10_loss: 0.5276 - val_c1_predictions_cifar10_accuracy: 0.9576 - val_c2_predictions_cifar10_accuracy: 0.8865 - val_predictions_cifar10_accuracy: 0.8358
# Epoch 15/60
# 391/391 [==============================] - 17s 44ms/step - loss: 0.2350 - c1_predictions_cifar10_loss: 0.0612 - c2_predictions_cifar10_loss: 0.2410 - predictions_cifar10_loss: 0.3612 - c1_predictions_cifar10_accuracy: 0.9765 - c2_predictions_cifar10_accuracy: 0.9147 - predictions_cifar10_accuracy: 0.8763 - val_loss: 0.3280 - val_c1_predictions_cifar10_loss: 0.1087 - val_c2_predictions_cifar10_loss: 0.3300 - val_predictions_cifar10_loss: 0.5312 - val_c1_predictions_cifar10_accuracy: 0.9586 - val_c2_predictions_cifar10_accuracy: 0.8930 - val_predictions_cifar10_accuracy: 0.8409
# Epoch 16/60
# 391/391 [==============================] - 18s 45ms/step - loss: 0.1984 - c1_predictions_cifar10_loss: 0.0597 - c2_predictions_cifar10_loss: 0.2023 - predictions_cifar10_loss: 0.3062 - c1_predictions_cifar10_accuracy: 0.9778 - c2_predictions_cifar10_accuracy: 0.9291 - predictions_cifar10_accuracy: 0.8944 - val_loss: 0.3219 - val_c1_predictions_cifar10_loss: 0.1098 - val_c2_predictions_cifar10_loss: 0.3219 - val_predictions_cifar10_loss: 0.5337 - val_c1_predictions_cifar10_accuracy: 0.9585 - val_c2_predictions_cifar10_accuracy: 0.8966 - val_predictions_cifar10_accuracy: 0.8417
# Epoch 17/60
# 391/391 [==============================] - 18s 45ms/step - loss: 0.1730 - c1_predictions_cifar10_loss: 0.0622 - c2_predictions_cifar10_loss: 0.1755 - predictions_cifar10_loss: 0.2637 - c1_predictions_cifar10_accuracy: 0.9772 - c2_predictions_cifar10_accuracy: 0.9389 - predictions_cifar10_accuracy: 0.9069 - val_loss: 0.3252 - val_c1_predictions_cifar10_loss: 0.1098 - val_c2_predictions_cifar10_loss: 0.3251 - val_predictions_cifar10_loss: 0.5407 - val_c1_predictions_cifar10_accuracy: 0.9580 - val_c2_predictions_cifar10_accuracy: 0.8965 - val_predictions_cifar10_accuracy: 0.8456
# Epoch 18/60
# 391/391 [==============================] - 18s 46ms/step - loss: 0.1443 - c1_predictions_cifar10_loss: 0.0553 - c2_predictions_cifar10_loss: 0.1452 - predictions_cifar10_loss: 0.2261 - c1_predictions_cifar10_accuracy: 0.9795 - c2_predictions_cifar10_accuracy: 0.9502 - predictions_cifar10_accuracy: 0.9201 - val_loss: 0.3448 - val_c1_predictions_cifar10_loss: 0.1140 - val_c2_predictions_cifar10_loss: 0.3476 - val_predictions_cifar10_loss: 0.5540 - val_c1_predictions_cifar10_accuracy: 0.9570 - val_c2_predictions_cifar10_accuracy: 0.8959 - val_predictions_cifar10_accuracy: 0.8444
# Epoch 19/60
# 391/391 [==============================] - 18s 46ms/step - loss: 0.1234 - c1_predictions_cifar10_loss: 0.0541 - c2_predictions_cifar10_loss: 0.1236 - predictions_cifar10_loss: 0.1912 - c1_predictions_cifar10_accuracy: 0.9800 - c2_predictions_cifar10_accuracy: 0.9564 - predictions_cifar10_accuracy: 0.9307 - val_loss: 0.3444 - val_c1_predictions_cifar10_loss: 0.1136 - val_c2_predictions_cifar10_loss: 0.3479 - val_predictions_cifar10_loss: 0.5471 - val_c1_predictions_cifar10_accuracy: 0.9590 - val_c2_predictions_cifar10_accuracy: 0.8992 - val_predictions_cifar10_accuracy: 0.8509
# Epoch 20/60
# 391/391 [==============================] - 18s 46ms/step - loss: 0.2714 - c1_predictions_cifar10_loss: 0.0558 - c2_predictions_cifar10_loss: 0.1170 - predictions_cifar10_loss: 0.3463 - c1_predictions_cifar10_accuracy: 0.9788 - c2_predictions_cifar10_accuracy: 0.9586 - predictions_cifar10_accuracy: 0.8853 - val_loss: 0.4982 - val_c1_predictions_cifar10_loss: 0.1160 - val_c2_predictions_cifar10_loss: 0.3422 - val_predictions_cifar10_loss: 0.5973 - val_c1_predictions_cifar10_accuracy: 0.9573 - val_c2_predictions_cifar10_accuracy: 0.9002 - val_predictions_cifar10_accuracy: 0.8320
# Epoch 21/60
# 391/391 [==============================] - 17s 45ms/step - loss: 0.2006 - c1_predictions_cifar10_loss: 0.0544 - c2_predictions_cifar10_loss: 0.1088 - predictions_cifar10_loss: 0.2477 - c1_predictions_cifar10_accuracy: 0.9797 - c2_predictions_cifar10_accuracy: 0.9623 - predictions_cifar10_accuracy: 0.9168 - val_loss: 0.5345 - val_c1_predictions_cifar10_loss: 0.1149 - val_c2_predictions_cifar10_loss: 0.3566 - val_predictions_cifar10_loss: 0.6453 - val_c1_predictions_cifar10_accuracy: 0.9576 - val_c2_predictions_cifar10_accuracy: 0.8940 - val_predictions_cifar10_accuracy: 0.8317
# Epoch 22/60
# 391/391 [==============================] - 17s 45ms/step - loss: 0.1386 - c1_predictions_cifar10_loss: 0.0528 - c2_predictions_cifar10_loss: 0.0933 - predictions_cifar10_loss: 0.1638 - c1_predictions_cifar10_accuracy: 0.9800 - c2_predictions_cifar10_accuracy: 0.9684 - predictions_cifar10_accuracy: 0.9431 - val_loss: 0.5011 - val_c1_predictions_cifar10_loss: 0.1115 - val_c2_predictions_cifar10_loss: 0.3521 - val_predictions_cifar10_loss: 0.5994 - val_c1_predictions_cifar10_accuracy: 0.9592 - val_c2_predictions_cifar10_accuracy: 0.8995 - val_predictions_cifar10_accuracy: 0.8521
# Epoch 23/60
# 391/391 [==============================] - 17s 44ms/step - loss: 0.1032 - c1_predictions_cifar10_loss: 0.0521 - c2_predictions_cifar10_loss: 0.0886 - predictions_cifar10_loss: 0.1147 - c1_predictions_cifar10_accuracy: 0.9806 - c2_predictions_cifar10_accuracy: 0.9692 - predictions_cifar10_accuracy: 0.9611 - val_loss: 0.5244 - val_c1_predictions_cifar10_loss: 0.1158 - val_c2_predictions_cifar10_loss: 0.3593 - val_predictions_cifar10_loss: 0.6299 - val_c1_predictions_cifar10_accuracy: 0.9581 - val_c2_predictions_cifar10_accuracy: 0.8978 - val_predictions_cifar10_accuracy: 0.8573
# Epoch 24/60
# 391/391 [==============================] - 17s 44ms/step - loss: 0.0817 - c1_predictions_cifar10_loss: 0.0502 - c2_predictions_cifar10_loss: 0.0797 - predictions_cifar10_loss: 0.0868 - c1_predictions_cifar10_accuracy: 0.9814 - c2_predictions_cifar10_accuracy: 0.9725 - predictions_cifar10_accuracy: 0.9706 - val_loss: 0.5693 - val_c1_predictions_cifar10_loss: 0.1139 - val_c2_predictions_cifar10_loss: 0.3511 - val_predictions_cifar10_loss: 0.6967 - val_c1_predictions_cifar10_accuracy: 0.9588 - val_c2_predictions_cifar10_accuracy: 0.8992 - val_predictions_cifar10_accuracy: 0.8545
# Epoch 25/60
# 391/391 [==============================] - 17s 44ms/step - loss: 0.0676 - c1_predictions_cifar10_loss: 0.0491 - c2_predictions_cifar10_loss: 0.0764 - predictions_cifar10_loss: 0.0678 - c1_predictions_cifar10_accuracy: 0.9812 - c2_predictions_cifar10_accuracy: 0.9732 - predictions_cifar10_accuracy: 0.9772 - val_loss: 0.6093 - val_c1_predictions_cifar10_loss: 0.1145 - val_c2_predictions_cifar10_loss: 0.3555 - val_predictions_cifar10_loss: 0.7525 - val_c1_predictions_cifar10_accuracy: 0.9598 - val_c2_predictions_cifar10_accuracy: 0.9014 - val_predictions_cifar10_accuracy: 0.8567
# Epoch 26/60
# 391/391 [==============================] - 17s 44ms/step - loss: 0.0622 - c1_predictions_cifar10_loss: 0.0487 - c2_predictions_cifar10_loss: 0.0726 - predictions_cifar10_loss: 0.0611 - c1_predictions_cifar10_accuracy: 0.9816 - c2_predictions_cifar10_accuracy: 0.9753 - predictions_cifar10_accuracy: 0.9791 - val_loss: 0.5983 - val_c1_predictions_cifar10_loss: 0.1136 - val_c2_predictions_cifar10_loss: 0.3557 - val_predictions_cifar10_loss: 0.7369 - val_c1_predictions_cifar10_accuracy: 0.9600 - val_c2_predictions_cifar10_accuracy: 0.9027 - val_predictions_cifar10_accuracy: 0.8568
# Epoch 27/60
# 391/391 [==============================] - 17s 45ms/step - loss: 0.0524 - c1_predictions_cifar10_loss: 0.0493 - c2_predictions_cifar10_loss: 0.0667 - predictions_cifar10_loss: 0.0487 - c1_predictions_cifar10_accuracy: 0.9812 - c2_predictions_cifar10_accuracy: 0.9773 - predictions_cifar10_accuracy: 0.9829 - val_loss: 0.6110 - val_c1_predictions_cifar10_loss: 0.1149 - val_c2_predictions_cifar10_loss: 0.3541 - val_predictions_cifar10_loss: 0.7552 - val_c1_predictions_cifar10_accuracy: 0.9605 - val_c2_predictions_cifar10_accuracy: 0.9034 - val_predictions_cifar10_accuracy: 0.8628
# Epoch 28/60
# 391/391 [==============================] - 18s 45ms/step - loss: 0.0405 - c1_predictions_cifar10_loss: 0.0469 - c2_predictions_cifar10_loss: 0.0588 - predictions_cifar10_loss: 0.0344 - c1_predictions_cifar10_accuracy: 0.9827 - c2_predictions_cifar10_accuracy: 0.9801 - predictions_cifar10_accuracy: 0.9885 - val_loss: 0.6353 - val_c1_predictions_cifar10_loss: 0.1142 - val_c2_predictions_cifar10_loss: 0.3628 - val_predictions_cifar10_loss: 0.7876 - val_c1_predictions_cifar10_accuracy: 0.9596 - val_c2_predictions_cifar10_accuracy: 0.9023 - val_predictions_cifar10_accuracy: 0.8638
# Epoch 29/60
# 391/391 [==============================] - 18s 46ms/step - loss: 0.0391 - c1_predictions_cifar10_loss: 0.0451 - c2_predictions_cifar10_loss: 0.0608 - predictions_cifar10_loss: 0.0321 - c1_predictions_cifar10_accuracy: 0.9834 - c2_predictions_cifar10_accuracy: 0.9794 - predictions_cifar10_accuracy: 0.9894 - val_loss: 0.6336 - val_c1_predictions_cifar10_loss: 0.1118 - val_c2_predictions_cifar10_loss: 0.3521 - val_predictions_cifar10_loss: 0.7885 - val_c1_predictions_cifar10_accuracy: 0.9614 - val_c2_predictions_cifar10_accuracy: 0.9055 - val_predictions_cifar10_accuracy: 0.8587
# Epoch 30/60
# 391/391 [==============================] - 18s 45ms/step - loss: 0.0792 - c1_predictions_cifar10_loss: 0.0455 - c2_predictions_cifar10_loss: 0.0721 - predictions_cifar10_loss: 0.0792 - c1_predictions_cifar10_accuracy: 0.9831 - c2_predictions_cifar10_accuracy: 0.9739 - predictions_cifar10_accuracy: 0.9742 - val_loss: 0.7532 - val_c1_predictions_cifar10_loss: 0.1203 - val_c2_predictions_cifar10_loss: 0.3832 - val_predictions_cifar10_loss: 0.7532 - val_c1_predictions_cifar10_accuracy: 0.9573 - val_c2_predictions_cifar10_accuracy: 0.8964 - val_predictions_cifar10_accuracy: 0.8517
# Epoch 31/60
# 391/391 [==============================] - 18s 45ms/step - loss: 0.0841 - c1_predictions_cifar10_loss: 0.0484 - c2_predictions_cifar10_loss: 0.0824 - predictions_cifar10_loss: 0.0841 - c1_predictions_cifar10_accuracy: 0.9823 - c2_predictions_cifar10_accuracy: 0.9716 - predictions_cifar10_accuracy: 0.9732 - val_loss: 0.7351 - val_c1_predictions_cifar10_loss: 0.1167 - val_c2_predictions_cifar10_loss: 0.3956 - val_predictions_cifar10_loss: 0.7351 - val_c1_predictions_cifar10_accuracy: 0.9575 - val_c2_predictions_cifar10_accuracy: 0.8942 - val_predictions_cifar10_accuracy: 0.8462
# Epoch 32/60
# 391/391 [==============================] - 18s 45ms/step - loss: 0.0549 - c1_predictions_cifar10_loss: 0.0481 - c2_predictions_cifar10_loss: 0.0799 - predictions_cifar10_loss: 0.0549 - c1_predictions_cifar10_accuracy: 0.9826 - c2_predictions_cifar10_accuracy: 0.9713 - predictions_cifar10_accuracy: 0.9823 - val_loss: 0.7240 - val_c1_predictions_cifar10_loss: 0.1170 - val_c2_predictions_cifar10_loss: 0.3881 - val_predictions_cifar10_loss: 0.7240 - val_c1_predictions_cifar10_accuracy: 0.9594 - val_c2_predictions_cifar10_accuracy: 0.8976 - val_predictions_cifar10_accuracy: 0.8594
# Epoch 33/60
# 391/391 [==============================] - 18s 45ms/step - loss: 0.0458 - c1_predictions_cifar10_loss: 0.0498 - c2_predictions_cifar10_loss: 0.0763 - predictions_cifar10_loss: 0.0458 - c1_predictions_cifar10_accuracy: 0.9816 - c2_predictions_cifar10_accuracy: 0.9728 - predictions_cifar10_accuracy: 0.9847 - val_loss: 0.7642 - val_c1_predictions_cifar10_loss: 0.1207 - val_c2_predictions_cifar10_loss: 0.3827 - val_predictions_cifar10_loss: 0.7642 - val_c1_predictions_cifar10_accuracy: 0.9585 - val_c2_predictions_cifar10_accuracy: 0.8979 - val_predictions_cifar10_accuracy: 0.8597
# Epoch 34/60
# 391/391 [==============================] - 18s 46ms/step - loss: 0.0503 - c1_predictions_cifar10_loss: 0.0512 - c2_predictions_cifar10_loss: 0.0812 - predictions_cifar10_loss: 0.0503 - c1_predictions_cifar10_accuracy: 0.9802 - c2_predictions_cifar10_accuracy: 0.9708 - predictions_cifar10_accuracy: 0.9831 - val_loss: 0.7846 - val_c1_predictions_cifar10_loss: 0.1197 - val_c2_predictions_cifar10_loss: 0.3747 - val_predictions_cifar10_loss: 0.7846 - val_c1_predictions_cifar10_accuracy: 0.9587 - val_c2_predictions_cifar10_accuracy: 0.8994 - val_predictions_cifar10_accuracy: 0.8567
# Epoch 35/60
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0390 - c1_predictions_cifar10_loss: 0.0502 - c2_predictions_cifar10_loss: 0.0800 - predictions_cifar10_loss: 0.0390 - c1_predictions_cifar10_accuracy: 0.9810 - c2_predictions_cifar10_accuracy: 0.9712 - predictions_cifar10_accuracy: 0.9868 - val_loss: 0.7589 - val_c1_predictions_cifar10_loss: 0.1169 - val_c2_predictions_cifar10_loss: 0.3746 - val_predictions_cifar10_loss: 0.7589 - val_c1_predictions_cifar10_accuracy: 0.9591 - val_c2_predictions_cifar10_accuracy: 0.8987 - val_predictions_cifar10_accuracy: 0.8646
# Epoch 36/60
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0293 - c1_predictions_cifar10_loss: 0.0480 - c2_predictions_cifar10_loss: 0.0792 - predictions_cifar10_loss: 0.0293 - c1_predictions_cifar10_accuracy: 0.9824 - c2_predictions_cifar10_accuracy: 0.9719 - predictions_cifar10_accuracy: 0.9907 - val_loss: 0.7660 - val_c1_predictions_cifar10_loss: 0.1183 - val_c2_predictions_cifar10_loss: 0.3729 - val_predictions_cifar10_loss: 0.7660 - val_c1_predictions_cifar10_accuracy: 0.9581 - val_c2_predictions_cifar10_accuracy: 0.8998 - val_predictions_cifar10_accuracy: 0.8673
# Epoch 37/60
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0264 - c1_predictions_cifar10_loss: 0.0475 - c2_predictions_cifar10_loss: 0.0810 - predictions_cifar10_loss: 0.0264 - c1_predictions_cifar10_accuracy: 0.9822 - c2_predictions_cifar10_accuracy: 0.9723 - predictions_cifar10_accuracy: 0.9912 - val_loss: 0.7662 - val_c1_predictions_cifar10_loss: 0.1171 - val_c2_predictions_cifar10_loss: 0.3660 - val_predictions_cifar10_loss: 0.7662 - val_c1_predictions_cifar10_accuracy: 0.9588 - val_c2_predictions_cifar10_accuracy: 0.9001 - val_predictions_cifar10_accuracy: 0.8710
# Epoch 38/60
# 391/391 [==============================] - 19s 48ms/step - loss: 0.0270 - c1_predictions_cifar10_loss: 0.0469 - c2_predictions_cifar10_loss: 0.0815 - predictions_cifar10_loss: 0.0270 - c1_predictions_cifar10_accuracy: 0.9824 - c2_predictions_cifar10_accuracy: 0.9709 - predictions_cifar10_accuracy: 0.9914 - val_loss: 0.7863 - val_c1_predictions_cifar10_loss: 0.1240 - val_c2_predictions_cifar10_loss: 0.3743 - val_predictions_cifar10_loss: 0.7863 - val_c1_predictions_cifar10_accuracy: 0.9580 - val_c2_predictions_cifar10_accuracy: 0.8993 - val_predictions_cifar10_accuracy: 0.8666
# Epoch 39/60
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0203 - c1_predictions_cifar10_loss: 0.0506 - c2_predictions_cifar10_loss: 0.0814 - predictions_cifar10_loss: 0.0203 - c1_predictions_cifar10_accuracy: 0.9811 - c2_predictions_cifar10_accuracy: 0.9712 - predictions_cifar10_accuracy: 0.9934 - val_loss: 0.8166 - val_c1_predictions_cifar10_loss: 0.1165 - val_c2_predictions_cifar10_loss: 0.3828 - val_predictions_cifar10_loss: 0.8166 - val_c1_predictions_cifar10_accuracy: 0.9586 - val_c2_predictions_cifar10_accuracy: 0.8962 - val_predictions_cifar10_accuracy: 0.8671
# Epoch 40/60
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0250 - c1_predictions_cifar10_loss: 0.0522 - c2_predictions_cifar10_loss: 0.0815 - predictions_cifar10_loss: 0.0250 - c1_predictions_cifar10_accuracy: 0.9806 - c2_predictions_cifar10_accuracy: 0.9709 - predictions_cifar10_accuracy: 0.9917 - val_loss: 0.7905 - val_c1_predictions_cifar10_loss: 0.1153 - val_c2_predictions_cifar10_loss: 0.3796 - val_predictions_cifar10_loss: 0.7905 - val_c1_predictions_cifar10_accuracy: 0.9593 - val_c2_predictions_cifar10_accuracy: 0.8962 - val_predictions_cifar10_accuracy: 0.8700
# Epoch 41/60
# 391/391 [==============================] - 19s 48ms/step - loss: 0.0222 - c1_predictions_cifar10_loss: 0.0519 - c2_predictions_cifar10_loss: 0.0835 - predictions_cifar10_loss: 0.0222 - c1_predictions_cifar10_accuracy: 0.9804 - c2_predictions_cifar10_accuracy: 0.9707 - predictions_cifar10_accuracy: 0.9929 - val_loss: 0.9014 - val_c1_predictions_cifar10_loss: 0.1199 - val_c2_predictions_cifar10_loss: 0.3839 - val_predictions_cifar10_loss: 0.9014 - val_c1_predictions_cifar10_accuracy: 0.9585 - val_c2_predictions_cifar10_accuracy: 0.8985 - val_predictions_cifar10_accuracy: 0.8605
# Epoch 42/60
# 391/391 [==============================] - 19s 48ms/step - loss: 0.0113 - c1_predictions_cifar10_loss: 0.0484 - c2_predictions_cifar10_loss: 0.0748 - predictions_cifar10_loss: 0.0113 - c1_predictions_cifar10_accuracy: 0.9817 - c2_predictions_cifar10_accuracy: 0.9741 - predictions_cifar10_accuracy: 0.9958 - val_loss: 0.7103 - val_c1_predictions_cifar10_loss: 0.1199 - val_c2_predictions_cifar10_loss: 0.3558 - val_predictions_cifar10_loss: 0.7103 - val_c1_predictions_cifar10_accuracy: 0.9589 - val_c2_predictions_cifar10_accuracy: 0.9025 - val_predictions_cifar10_accuracy: 0.8808
# Epoch 43/60
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0037 - c1_predictions_cifar10_loss: 0.0502 - c2_predictions_cifar10_loss: 0.0681 - predictions_cifar10_loss: 0.0037 - c1_predictions_cifar10_accuracy: 0.9804 - c2_predictions_cifar10_accuracy: 0.9774 - predictions_cifar10_accuracy: 0.9989 - val_loss: 0.7070 - val_c1_predictions_cifar10_loss: 0.1179 - val_c2_predictions_cifar10_loss: 0.3535 - val_predictions_cifar10_loss: 0.7070 - val_c1_predictions_cifar10_accuracy: 0.9588 - val_c2_predictions_cifar10_accuracy: 0.9034 - val_predictions_cifar10_accuracy: 0.8831
# Epoch 44/60
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0031 - c1_predictions_cifar10_loss: 0.0495 - c2_predictions_cifar10_loss: 0.0674 - predictions_cifar10_loss: 0.0031 - c1_predictions_cifar10_accuracy: 0.9812 - c2_predictions_cifar10_accuracy: 0.9769 - predictions_cifar10_accuracy: 0.9993 - val_loss: 0.7058 - val_c1_predictions_cifar10_loss: 0.1181 - val_c2_predictions_cifar10_loss: 0.3535 - val_predictions_cifar10_loss: 0.7058 - val_c1_predictions_cifar10_accuracy: 0.9591 - val_c2_predictions_cifar10_accuracy: 0.9019 - val_predictions_cifar10_accuracy: 0.8830
# Epoch 45/60
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0019 - c1_predictions_cifar10_loss: 0.0497 - c2_predictions_cifar10_loss: 0.0676 - predictions_cifar10_loss: 0.0019 - c1_predictions_cifar10_accuracy: 0.9809 - c2_predictions_cifar10_accuracy: 0.9760 - predictions_cifar10_accuracy: 0.9994 - val_loss: 0.7074 - val_c1_predictions_cifar10_loss: 0.1174 - val_c2_predictions_cifar10_loss: 0.3517 - val_predictions_cifar10_loss: 0.7074 - val_c1_predictions_cifar10_accuracy: 0.9590 - val_c2_predictions_cifar10_accuracy: 0.9030 - val_predictions_cifar10_accuracy: 0.8834
# Epoch 46/60
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0016 - c1_predictions_cifar10_loss: 0.0476 - c2_predictions_cifar10_loss: 0.0656 - predictions_cifar10_loss: 0.0016 - c1_predictions_cifar10_accuracy: 0.9818 - c2_predictions_cifar10_accuracy: 0.9771 - predictions_cifar10_accuracy: 0.9997 - val_loss: 0.7075 - val_c1_predictions_cifar10_loss: 0.1177 - val_c2_predictions_cifar10_loss: 0.3509 - val_predictions_cifar10_loss: 0.7075 - val_c1_predictions_cifar10_accuracy: 0.9592 - val_c2_predictions_cifar10_accuracy: 0.9031 - val_predictions_cifar10_accuracy: 0.8850
# Epoch 47/60
# 391/391 [==============================] - 19s 48ms/step - loss: 0.0012 - c1_predictions_cifar10_loss: 0.0500 - c2_predictions_cifar10_loss: 0.0667 - predictions_cifar10_loss: 0.0012 - c1_predictions_cifar10_accuracy: 0.9813 - c2_predictions_cifar10_accuracy: 0.9770 - predictions_cifar10_accuracy: 0.9997 - val_loss: 0.7110 - val_c1_predictions_cifar10_loss: 0.1172 - val_c2_predictions_cifar10_loss: 0.3514 - val_predictions_cifar10_loss: 0.7110 - val_c1_predictions_cifar10_accuracy: 0.9595 - val_c2_predictions_cifar10_accuracy: 0.9031 - val_predictions_cifar10_accuracy: 0.8846
# Epoch 48/60
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0016 - c1_predictions_cifar10_loss: 0.0492 - c2_predictions_cifar10_loss: 0.0659 - predictions_cifar10_loss: 0.0016 - c1_predictions_cifar10_accuracy: 0.9814 - c2_predictions_cifar10_accuracy: 0.9772 - predictions_cifar10_accuracy: 0.9995 - val_loss: 0.7155 - val_c1_predictions_cifar10_loss: 0.1172 - val_c2_predictions_cifar10_loss: 0.3517 - val_predictions_cifar10_loss: 0.7155 - val_c1_predictions_cifar10_accuracy: 0.9592 - val_c2_predictions_cifar10_accuracy: 0.9027 - val_predictions_cifar10_accuracy: 0.8840
# Epoch 49/60
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0011 - c1_predictions_cifar10_loss: 0.0480 - c2_predictions_cifar10_loss: 0.0645 - predictions_cifar10_loss: 0.0011 - c1_predictions_cifar10_accuracy: 0.9814 - c2_predictions_cifar10_accuracy: 0.9777 - predictions_cifar10_accuracy: 0.9997 - val_loss: 0.7176 - val_c1_predictions_cifar10_loss: 0.1179 - val_c2_predictions_cifar10_loss: 0.3510 - val_predictions_cifar10_loss: 0.7176 - val_c1_predictions_cifar10_accuracy: 0.9589 - val_c2_predictions_cifar10_accuracy: 0.9029 - val_predictions_cifar10_accuracy: 0.8837
# Epoch 50/60
# 391/391 [==============================] - 19s 47ms/step - loss: 9.2122e-04 - c1_predictions_cifar10_loss: 0.0501 - c2_predictions_cifar10_loss: 0.0646 - predictions_cifar10_loss: 9.2122e-04 - c1_predictions_cifar10_accuracy: 0.9807 - c2_predictions_cifar10_accuracy: 0.9774 - predictions_cifar10_accuracy: 0.9998 - val_loss: 0.7191 - val_c1_predictions_cifar10_loss: 0.1172 - val_c2_predictions_cifar10_loss: 0.3497 - val_predictions_cifar10_loss: 0.7191 - val_c1_predictions_cifar10_accuracy: 0.9595 - val_c2_predictions_cifar10_accuracy: 0.9032 - val_predictions_cifar10_accuracy: 0.8830
# Epoch 51/60
# 391/391 [==============================] - 18s 46ms/step - loss: 8.7714e-04 - c1_predictions_cifar10_loss: 0.0493 - c2_predictions_cifar10_loss: 0.0627 - predictions_cifar10_loss: 8.7714e-04 - c1_predictions_cifar10_accuracy: 0.9813 - c2_predictions_cifar10_accuracy: 0.9785 - predictions_cifar10_accuracy: 0.9999 - val_loss: 0.7214 - val_c1_predictions_cifar10_loss: 0.1177 - val_c2_predictions_cifar10_loss: 0.3501 - val_predictions_cifar10_loss: 0.7214 - val_c1_predictions_cifar10_accuracy: 0.9597 - val_c2_predictions_cifar10_accuracy: 0.9034 - val_predictions_cifar10_accuracy: 0.8834
# Epoch 52/60
# 391/391 [==============================] - 18s 47ms/step - loss: 0.0010 - c1_predictions_cifar10_loss: 0.0472 - c2_predictions_cifar10_loss: 0.0622 - predictions_cifar10_loss: 0.0010 - c1_predictions_cifar10_accuracy: 0.9825 - c2_predictions_cifar10_accuracy: 0.9791 - predictions_cifar10_accuracy: 0.9998 - val_loss: 0.7207 - val_c1_predictions_cifar10_loss: 0.1175 - val_c2_predictions_cifar10_loss: 0.3501 - val_predictions_cifar10_loss: 0.7207 - val_c1_predictions_cifar10_accuracy: 0.9594 - val_c2_predictions_cifar10_accuracy: 0.9036 - val_predictions_cifar10_accuracy: 0.8833
# Epoch 53/60
# 391/391 [==============================] - 18s 47ms/step - loss: 7.7186e-04 - c1_predictions_cifar10_loss: 0.0495 - c2_predictions_cifar10_loss: 0.0643 - predictions_cifar10_loss: 7.7186e-04 - c1_predictions_cifar10_accuracy: 0.9818 - c2_predictions_cifar10_accuracy: 0.9775 - predictions_cifar10_accuracy: 0.9998 - val_loss: 0.7223 - val_c1_predictions_cifar10_loss: 0.1180 - val_c2_predictions_cifar10_loss: 0.3506 - val_predictions_cifar10_loss: 0.7223 - val_c1_predictions_cifar10_accuracy: 0.9594 - val_c2_predictions_cifar10_accuracy: 0.9032 - val_predictions_cifar10_accuracy: 0.8828
# Epoch 54/60
# 391/391 [==============================] - 18s 46ms/step - loss: 9.8405e-04 - c1_predictions_cifar10_loss: 0.0482 - c2_predictions_cifar10_loss: 0.0640 - predictions_cifar10_loss: 9.8405e-04 - c1_predictions_cifar10_accuracy: 0.9819 - c2_predictions_cifar10_accuracy: 0.9774 - predictions_cifar10_accuracy: 0.9998 - val_loss: 0.7232 - val_c1_predictions_cifar10_loss: 0.1169 - val_c2_predictions_cifar10_loss: 0.3497 - val_predictions_cifar10_loss: 0.7232 - val_c1_predictions_cifar10_accuracy: 0.9596 - val_c2_predictions_cifar10_accuracy: 0.9030 - val_predictions_cifar10_accuracy: 0.8832
# Epoch 55/60
# 391/391 [==============================] - 17s 44ms/step - loss: 0.0011 - c1_predictions_cifar10_loss: 0.0472 - c2_predictions_cifar10_loss: 0.0642 - predictions_cifar10_loss: 0.0011 - c1_predictions_cifar10_accuracy: 0.9821 - c2_predictions_cifar10_accuracy: 0.9781 - predictions_cifar10_accuracy: 0.9998 - val_loss: 0.7239 - val_c1_predictions_cifar10_loss: 0.1170 - val_c2_predictions_cifar10_loss: 0.3503 - val_predictions_cifar10_loss: 0.7239 - val_c1_predictions_cifar10_accuracy: 0.9594 - val_c2_predictions_cifar10_accuracy: 0.9031 - val_predictions_cifar10_accuracy: 0.8830
# Epoch 56/60
# 391/391 [==============================] - 18s 45ms/step - loss: 9.7878e-04 - c1_predictions_cifar10_loss: 0.0489 - c2_predictions_cifar10_loss: 0.0635 - predictions_cifar10_loss: 9.7878e-04 - c1_predictions_cifar10_accuracy: 0.9810 - c2_predictions_cifar10_accuracy: 0.9783 - predictions_cifar10_accuracy: 0.9997 - val_loss: 0.7239 - val_c1_predictions_cifar10_loss: 0.1167 - val_c2_predictions_cifar10_loss: 0.3496 - val_predictions_cifar10_loss: 0.7239 - val_c1_predictions_cifar10_accuracy: 0.9594 - val_c2_predictions_cifar10_accuracy: 0.9032 - val_predictions_cifar10_accuracy: 0.8837
# Epoch 57/60
# 391/391 [==============================] - 17s 44ms/step - loss: 8.2437e-04 - c1_predictions_cifar10_loss: 0.0490 - c2_predictions_cifar10_loss: 0.0626 - predictions_cifar10_loss: 8.2437e-04 - c1_predictions_cifar10_accuracy: 0.9815 - c2_predictions_cifar10_accuracy: 0.9791 - predictions_cifar10_accuracy: 0.9998 - val_loss: 0.7242 - val_c1_predictions_cifar10_loss: 0.1164 - val_c2_predictions_cifar10_loss: 0.3495 - val_predictions_cifar10_loss: 0.7242 - val_c1_predictions_cifar10_accuracy: 0.9595 - val_c2_predictions_cifar10_accuracy: 0.9034 - val_predictions_cifar10_accuracy: 0.8835
# Epoch 58/60
# 391/391 [==============================] - 17s 44ms/step - loss: 8.0374e-04 - c1_predictions_cifar10_loss: 0.0482 - c2_predictions_cifar10_loss: 0.0655 - predictions_cifar10_loss: 8.0374e-04 - c1_predictions_cifar10_accuracy: 0.9819 - c2_predictions_cifar10_accuracy: 0.9769 - predictions_cifar10_accuracy: 0.9999 - val_loss: 0.7246 - val_c1_predictions_cifar10_loss: 0.1175 - val_c2_predictions_cifar10_loss: 0.3501 - val_predictions_cifar10_loss: 0.7246 - val_c1_predictions_cifar10_accuracy: 0.9591 - val_c2_predictions_cifar10_accuracy: 0.9028 - val_predictions_cifar10_accuracy: 0.8832
# Epoch 59/60
# 391/391 [==============================] - 17s 44ms/step - loss: 9.1078e-04 - c1_predictions_cifar10_loss: 0.0500 - c2_predictions_cifar10_loss: 0.0649 - predictions_cifar10_loss: 9.1078e-04 - c1_predictions_cifar10_accuracy: 0.9812 - c2_predictions_cifar10_accuracy: 0.9778 - predictions_cifar10_accuracy: 0.9998 - val_loss: 0.7234 - val_c1_predictions_cifar10_loss: 0.1170 - val_c2_predictions_cifar10_loss: 0.3492 - val_predictions_cifar10_loss: 0.7234 - val_c1_predictions_cifar10_accuracy: 0.9594 - val_c2_predictions_cifar10_accuracy: 0.9035 - val_predictions_cifar10_accuracy: 0.8839
# Epoch 60/60
# 391/391 [==============================] - 17s 43ms/step - loss: 8.2616e-04 - c1_predictions_cifar10_loss: 0.0493 - c2_predictions_cifar10_loss: 0.0658 - predictions_cifar10_loss: 8.2616e-04 - c1_predictions_cifar10_accuracy: 0.9815 - c2_predictions_cifar10_accuracy: 0.9777 - predictions_cifar10_accuracy: 0.9998 - val_loss: 0.7249 - val_c1_predictions_cifar10_loss: 0.1165 - val_c2_predictions_cifar10_loss: 0.3496 - val_predictions_cifar10_loss: 0.7249 - val_c1_predictions_cifar10_accuracy: 0.9596 - val_c2_predictions_cifar10_accuracy: 0.9027 - val_predictions_cifar10_accuracy: 0.8838
# score is:  [1.1909830570220947, 0.11649880558252335, 0.34962087869644165, 0.7248638272285461, 0.9595000147819519, 0.9027000069618225, 0.8838000297546387]

# %% [markdown]
# # Plot& Evaluation

# %%
plot.rcdefaults ()
plot.plot(trained.history['predictions_cifar10_accuracy'])
plot.plot(trained.history['val_predictions_cifar10_accuracy'])
plot.title('Model accuracy')
plot.ylabel('Accuracy')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()


plot.plot(trained.history['predictions_cifar10_loss'])
plot.plot(trained.history['val_predictions_cifar10_loss'])
plot.title('Model loss')
plot.ylabel('Loss')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

# %%
predictions = model.predict(x_test)     # Vector of probabilities
pred_labels = np.argmax(predictions[-1], axis = 1) # We take the highest probability

# %%
test_labels = np.argmax(y_test, axis = 1)
CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sn.heatmap(CM, annot=True,
           cmap=plt.cm.Blues,
           annot_kws={"size": 10}, 
           xticklabels=classes, 
           yticklabels=classes, ax = ax, fmt="d")

plt.xticks(rotation=30)
ax.set_title('Confusion matrix')

plt.show()

# %% [markdown]
# # Miss classification sample

# %%
def print_mislabeled_images(class_names, test_images, test_labels, pred_labels):
    """
        Print 25 examples of mislabeled images by the classifier, e.g when test_labels != pred_labels
    """
    BOO = (test_labels == pred_labels)
    mislabeled_indices = np.where(BOO == 0)
    mislabeled_images = test_images[mislabeled_indices]
    mislabeled_labels = pred_labels[mislabeled_indices]

    title = "Some examples of mislabeled images by the classifier:"
    display_examples(class_names,  mislabeled_images, mislabeled_labels, title)

print_mislabeled_images(classes, test_images, test_labels, pred_labels)

# %%
from PIL import Image, ImageChops
latest = model_path
latest

model.load_weights(latest)
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
im = Image.open("coco.jpg")
plt.imshow(im)
im = im.resize((32,32))
im = np.array(im, dtype = 'float32')
output = np.expand_dims(im, axis = 0)
x = model.predict(output)
print(classes[np.argmax(x[-1], axis = 1)[0]])
# Out:
# cat
